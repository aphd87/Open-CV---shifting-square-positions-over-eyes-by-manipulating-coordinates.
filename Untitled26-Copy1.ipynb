# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Processing grayscale imageshttp://localhost:8888/notebooks/Untitled26-Copy1.ipynb#
im = plt.imread(r'ladygaga.jpg')
im2 = im.copy()
im2[200:300,250:350] = 255 #for left eye
im2[200:300,380:480] = 255 #for right eye 
plt.imshow(im2,cmap='gray') #There is a white patch here.
